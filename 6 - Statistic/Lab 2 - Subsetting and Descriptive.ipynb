# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in this lab's data folder.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
temp = pd.read_csv('/Users/alessandra/Documents/Ironhack/Curso/Data/Temp_States.csv', sep=';')
temp.head(10)
# Out:
#          City        State  Temperature  Unnamed: 3
# 0         NYC     New York    19.444444         NaN
# 1      Albany     New York     9.444444         NaN
# 2     Buffalo     New York     3.333333         NaN
# 3    Hartford  Connecticut    17.222222         NaN
# 4  Bridgeport  Connecticut    14.444444         NaN
# 5      Treton   New Jersey    22.222222         NaN
# 6      Newark   New Jersey    20.000000         NaN

# %% [markdown]
# #### Print `temp`.

# %%
print(temp)
# Out:
#          City        State  Temperature  Unnamed: 3
# 0         NYC     New York    19.444444         NaN
# 1      Albany     New York     9.444444         NaN
# 2     Buffalo     New York     3.333333         NaN
# 3    Hartford  Connecticut    17.222222         NaN
# 4  Bridgeport  Connecticut    14.444444         NaN
# 5      Treton   New Jersey    22.222222         NaN
# 6      Newark   New Jersey    20.000000         NaN

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# Unnamed: 3     float64
# dtype: object

# %% [markdown]
# **Answer: We have the columns City as object, State as object and Temperature as float.**

# %% [markdown]
# #### Select the rows where state is New York.

# %%
temp.loc[temp['State'] == 'New York']
# Out:
#       City     State  Temperature  Unnamed: 3
# 0      NYC  New York    19.444444         NaN
# 1   Albany  New York     9.444444         NaN
# 2  Buffalo  New York     3.333333         NaN

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
temp.loc[temp['State'] == 'New York'].mean()
# Out:
# Temperature    10.740741
# Unnamed: 3           NaN
# dtype: float64

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
temp.loc[(temp['Temperature'] > 15)]
# Out:
#        City        State  Temperature  Unnamed: 3
# 0       NYC     New York    19.444444         NaN
# 3  Hartford  Connecticut    17.222222         NaN
# 5    Treton   New Jersey    22.222222         NaN
# 6    Newark   New Jersey    20.000000         NaN

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
temp.loc[(temp['Temperature'] > 15)][['City', 'Temperature']]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
temp.loc[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)][['City', 'Temperature']]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
temp.groupby(['State'])[['Temperature']].mean()
# Out:
#              Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741

# %%
temp.groupby(['State'])[['Temperature']].std()
# Out:
#              Temperature
# State
# Connecticut     1.964186
# New Jersey      1.571348
# New York        8.133404

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
employees = pd.read_csv('/Users/alessandra/Documents/Ironhack/Curso/Data/employees.csv', sep=';')
employees.head(10)
# Out:
#      Name Department Education Gender      Title  Years  Salary  Unnamed: 7
# 0    Jose         IT  Bachelor      M    analyst      1      35         NaN
# 1   Maria         IT    Master      F    analyst      2      30         NaN
# 2   David         HR    Master      M    analyst      2      30         NaN
# 3   Sonia         HR  Bachelor      F    analyst      4      35         NaN
# 4  Samuel      Sales    Master      M  associate      3      55         NaN
# 5     Eva      Sales  Bachelor      F  associate      2      55         NaN
# 6  Carlos         IT    Master      M         VP      8      70         NaN
# 7   Pedro         IT       Phd      M  associate      7      60         NaN
# 8     Ana         HR    Master      F         VP      8      70         NaN

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
employees.dtypes
# Out:
# Name           object
# Department     object
# Education      object
# Gender         object
# Title          object
# Years           int64
# Salary          int64
# Unnamed: 7    float64
# dtype: object

# %% [markdown]
# **Answer: We have the columns Name, Department, Education, Gender and Title as object, the columns Years and Salary as integer.**

# %% [markdown]
# #### What's the average salary in this company?

# %%
employees['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
employees['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
employees[['Name', 'Salary']].min()
# Out:
# Name      Ana
# Salary     30
# dtype: object

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
employees.loc[employees['Name'] == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary  Unnamed: 7
# 2  David         HR    Master      M  analyst      2      30         NaN

# %% [markdown]
# #### Could you return only David's salary?

# %%
employees.loc[employees['Name'] == 'David']['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
employees.loc[employees['Title'] == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary  Unnamed: 7
# 4  Samuel      Sales    Master      M  associate      3      55         NaN
# 5     Eva      Sales  Bachelor      F  associate      2      55         NaN
# 7   Pedro         IT       Phd      M  associate      7      60         NaN

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
employees.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary  Unnamed: 7
# 0   Jose         IT  Bachelor      M  analyst      1      35         NaN
# 1  Maria         IT    Master      F  analyst      2      30         NaN
# 2  David         HR    Master      M  analyst      2      30         NaN

# %%
employees.loc[0:3,:]
# Out:
#     Name Department Education Gender    Title  Years  Salary  Unnamed: 7
# 0   Jose         IT  Bachelor      M  analyst      1      35         NaN
# 1  Maria         IT    Master      F  analyst      2      30         NaN
# 2  David         HR    Master      M  analyst      2      30         NaN
# 3  Sonia         HR  Bachelor      F  analyst      4      35         NaN

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
employees.loc[(employees['Title'] == 'associate') & (employees['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary  Unnamed: 7
# 7  Pedro         IT       Phd      M  associate      7      60         NaN

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
employees.groupby(['Years'])[['Salary']].mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average salary per title?

# %%
employees.groupby(['Title'])[['Salary']].mean()
# Out:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# ####  Find the salary quartiles.

# %%
employees['Salary'].describe()
# Out:
# count     9.000000
# mean     48.888889
# std      16.541194
# min      30.000000
# 25%      35.000000
# 50%      55.000000
# 75%      60.000000
# max      70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
employees.groupby(['Gender'])[['Salary']].mean()
# Out:
#         Salary
# Gender
# F         47.5
# M         50.0

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
employees.groupby('Department').describe(include= 'int64').T
# Out:
# Department           HR         IT      Sales
# Years  count   3.000000   4.000000   2.000000
#        mean    4.666667   4.500000   2.500000
#        std     3.055050   3.511885   0.707107
#        min     2.000000   1.000000   2.000000
#        25%     3.000000   1.750000   2.250000
#        50%     4.000000   4.500000   2.500000
#        75%     6.000000   7.250000   2.750000
#        max     8.000000   8.000000   3.000000
# Salary count   3.000000   4.000000   2.000000
#        mean   45.000000  48.750000  55.000000
#        std    21.794495  19.311050   0.000000
#        min    30.000000  30.000000  55.000000
#        25%    32.500000  33.750000  55.000000
#        50%    35.000000  47.500000  55.000000
#        75%    52.500000  62.500000  55.000000
#        max    70.000000  70.000000  55.000000

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
employees.groupby(['Department'])['Salary'].apply(lambda x : x.max() - x.min())
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# Name: Salary, dtype: int64

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
orders = pd.read_csv('/Users/alessandra/Documents/Ironhack/Curso/Data/Orders.csv')
orders.head(10)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
# 5           5     536365     22752  2010     12    3     8
# 6           6     536365     21730  2010     12    3     8
# 7           7     536366     22633  2010     12    3     8
# 8           8     536366     22632  2010     12    3     8
# 9           9     536367     84879  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# **Answer: The Database has 13 columns - 7 integer, 4 object and 2 float. Some important things to observe: we have 397.924 orders in total and this database comprises the years 2010 and 2011. It has outlier in Quantity, because we can see that the standard deviation is very large and the mean is 13, but we have a maximum number as 80.995 (very different with we compare to the mean). The price stops in the maximum value of 8.143 and, if we compare to the mean of 3, we can see that the mean is not good to represents this category. Finally, the mean of amount spent is not good to describe this category too, as we can see that we have a large standard deviation and range between the minimum and maximum.**

# %% [markdown]
# ####  What is the average purchase price?

# %%
orders['amount_spent'].mean()
# Out:
# 22.394748504739596

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
orders['amount_spent'].max()
# Out:
# 168469.6

# %%
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
customers_spain = orders.loc[(orders['Country'] == 'Spain')].groupby(['CustomerID'])[['Quantity', 'UnitPrice', 'amount_spent']].mean()
customers_spain
# Out:
#               Quantity  UnitPrice  amount_spent
# CustomerID
# 12354         9.137931   4.503793     18.610345
# 12417        11.608696   3.132609     18.969565
# 12421        10.755556   4.520222     17.934222
# 12442        15.166667   3.340000     14.338333
# 12445        15.500000   7.987500     33.350000
# 12448        11.045455   5.951818     20.429545
# 12450        16.000000   1.617500     24.735000
# 12454        67.066667   7.282000    235.222667
# 12455        11.791667   3.692500     15.999167
# 12462         8.645161   4.689516     19.186935
# 12484         6.332370   3.126098     13.126358
# 12502         5.578231   6.425238     25.332449
# 12507        41.136364   4.641818     59.309545
# 12510        10.696970   4.263333     29.774848
# 12538         9.095238   3.643333     17.330952
# 12539         7.571429   4.176520     20.396886
# 12540        13.985356   3.847050     28.033975
# 12541        13.076923   3.615769     18.868846
# ...

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
customers_spain.shape
# Out:
# (30, 3)

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
customers_quantity = orders.loc[(orders['Quantity'] > 50)].groupby(['CustomerID'])[['Quantity']]
customers_quantity.describe()
# Out:
#            Quantity                                                       \
#               count          mean         std      min      25%      50%
# CustomerID
# 12346           1.0  74215.000000         NaN  74215.0  74215.0  74215.0
# 12347           1.0    240.000000         NaN    240.0    240.0    240.0
# 12348          19.0    110.315789   29.763984     72.0     76.0    120.0
# 12355           2.0     78.000000   25.455844     60.0     69.0     78.0
# 12356           5.0     88.800000   28.899827     60.0     72.0     72.0
# ...             ...           ...         ...      ...      ...      ...
# 18246           2.0     70.000000   14.142136     60.0     65.0     70.0
# 18248           1.0     72.000000         NaN     72.0     72.0     72.0
# 18251          16.0    489.000000  158.926398     72.0    432.0    528.0
# 18260           1.0     96.000000         NaN     96.0     96.0     96.0
# 18287           1.0     60.000000         NaN     60.0     60.0     60.0
#
#
# ...

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
orders.loc[(orders['Country'] == 'Spain') & (orders['Quantity'] > 50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders.

# %%
orders.loc[(orders['UnitPrice'] == 0)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
orders.loc[(orders['Description'].apply(lambda x : x.startswith('lunch bag')))]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
orders[(orders['Description'].apply(lambda x : x.startswith('lunch bag'))) & (orders['year'] == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
amountspent_spain = orders.loc[(orders['Country'] == 'Spain')]['amount_spent']
amountspent_spain.plot(kind='hist')

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
orders.loc[(orders['month'] == 8)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
orders_countries = orders.loc[(orders['month'] == 8)]['Country']

orders_countries.value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
orders.groupby(['Country'])[['amount_spent']].mean()
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
orders.groupby(['year'])[['amount_spent']].mean()
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
